# %%
#Part 1 - Building CNN
#Importing Keras libraries and packages
from keras.models import Sequential #to initialize NN
# from keras.layers import Conv2D #step 1 - adding convolution layers, 2D bc images
# from keras.layers import MaxPooling2D #step 2 - pooling step
# from keras.layers import Flatten #step 3 - convert pooled feature maps into large feature vector
from keras.layers import Dense #to add fully-connected layers and NN
from keras.applications.resnet50 import ResNet50
# Out:
# C:\Users\Shaina\Anaconda3\lib\site-packages\h5py\__init__.py:72: UserWarning: h5py is running against HDF5 1.10.2 when it was built against 1.10.3, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
# Using TensorFlow backend.
# C:\Users\Shaina\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Shaina\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...

# %%
weights_path = './resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'
num_classes = 4

# %%
#Initializing the CNN
classifier = Sequential()

# %%
classifier.add(ResNet50(include_top=False,
                       weights=weights_path,
                       pooling='avg'))
classifier.add(Dense(num_classes, activation='softmax'))
classifier.layers[0].trainable=False
# Out:
# WARNING:tensorflow:From C:\Users\Shaina\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-341c547e7e0d> in <module>
#       1 classifier.add(ResNet50(include_top=False,
#       2                        weights=weights_path,
# ----> 3                        pooling='avg'))
#       4 classifier.add(Dense(num_classes, activation='softmax'))
#       5 classifier.layers[0].trainable=False
#
# ~\Anaconda3\lib\site-packages\keras\applications\__init__.py in wrapper(*args, **kwargs)
#      18         kwargs['models'] = models
#      19         kwargs['utils'] = utils
# ...

# %%
#Step 1 - Convolution
# classifier.add(Conv2D(32, (3, 3), input_shape=(128, 128, 3), activation ='relu'))  

#Conv2D(number of filters, (row,col of feature detector))
#input_shape: 3 number of channels for RGB, 2 for black and white; 256 dimensions of 2D array in each of the channel

# %%
#Step 2 - Pooling
# classifier.add(MaxPooling2D(pool_size=(2, 2)))
#dimensions of feature map

# %%
#Another Convolutional Layer
# classifier.add(Conv2D(64, (3, 3), activation ='relu')) #3 channels, 64 - dimensions od 2D array
# classifier.add(MaxPooling2D(pool_size=(2, 2)))

#classifier.add(Conv2D(32, (3, 3), activation ='relu')) #3 channels, 64 - dimensions od 2D array
#classifier.add(MaxPooling2D(pool_size=(2, 2)))

# %%
# classifier.add(Flatten())

#flatten 2D array to 1D array

# %%
#Step 4
# classifier.add(Dense(units = 128, activation = 'relu')) 
#to add fully connected layer, 128 # of hidden layer, # of nodes in hidden layer, should be a power of 2
# classifier.add(Dense(units = 4, activation = 'softmax'))
#units expected classification
#sigmoid if 2 outcomes, softmax if more than 2

# %%
#Compiling the CNN
# classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
classifier.compile(optimizer = 'sgd', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
#Fitting CNN to images
from keras.preprocessing.image import ImageDataGenerator

data_generator = ImageDataGenerator(preprocessing_function=progress_input)

# %%
# train_datagen = ImageDataGenerator(
#         rescale=1./255, #all pixel values will be ebtween 0 and 1
#         shear_range=0.2, #transvections
#         zoom_range=0.2, #random zooms
#         horizontal_flip=True) #flipped horizontally

# %%
# test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# training_set = train_datagen.flow_from_directory('dataset/training_set',
#                                                 target_size=(128, 128), #size of images expected by CNN model
#                                                 batch_size=4, 
#                                                 class_mode='categorical')

train_set = data_generator.flow_from_directory('dataset/training_set',
                                                target_size=(128, 128), #size of images expected by CNN model
                                                batch_size=4, 
                                                class_mode='categorical')

# %%
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size=(128, 128),
                                            batch_size=2,
                                            class_mode='categorical')

# %%
classifier.fit_generator(training_set,
                        steps_per_epoch=35,
#                         epochs=50,
                        validation_data=test_set
                        validation_steps=1)
